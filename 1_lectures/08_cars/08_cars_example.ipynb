# %% [markdown]
# # Introduction
#
# ### Økonometri A (ØkA)
#
# ### Empirisk eksempel: The Evolution of Market Power in the U.S. Automobile Industry
#
# Grieco, P.L.E., Murry, C. and Yurukoglu, A. (2024): "The Evolution of Market Power in the U.S. Automobile Industry."
# <br>*The Quarterly Journal of Economics*, 139(2), pp.1201-1253.
#
# Bertel Schjerning
#
# Department of Economics, University of Copenhagen
#
# ## Outline
#
# 1. En økonomisk model for bilefterspørgsel
# 2. Data, deskriptiv analyse og multikollinearitet
# 3. OLS, specifikationstest og Frisch-Waugh-Lovell
# 4. Fixed effects og within-transformation
# 5. Elasticiteter, substitution, IIA og markups
# 6. Endogenitet og instrumentvariable
# 7. Bro til heteroskedasticitet

# %% [markdown]
# # Part 1: En logitmodel for efterspørgslen efter biler
#
# ## Hvorfor estimere efterspørgsel?
#
# En efterspørgselsmodel kan bruges til at undersøge:
#
# - hvor følsomt bilsalget er over for priser,
# - hvilke biler der er nære substitutter,
# - virksomheders markups og marginalomkostninger, og
# - hvordan markedet reagerer på nye produkter, afgifter eller andre ændringer.

# %% [markdown]
# ## Modellering af Markedsandele: Logit Model
#
# **Nyttefunktion for Forbruger $i$, Produkt $j$ i Marked $m$:**
#
# $$
# U_{imj} = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj} + \epsilon_{imj} = V_{mj}+\epsilon_{imj}, \qquad \alpha<0
# $$
#
# - $\mathbf{x}_{mj}$: Observerbare karakteristika for produkt $j$ i marked $m$ (f.eks. størrelse, kvalitet).
# - $p_{mj}$: Pris for produkt $j$ i marked $m$; vi forventer $\alpha<0$.
# - $\xi_{mj}$: Uobserverbare karakteristika (f.eks. brand, placering).
# - $\epsilon_{imj}$: Idiosynkratisk fejlled, der følger en ekstremværdi fordeling (Gumbel).
#
# **Markedsandel for Produkt $j$ i Marked $m$:**
#
# Forbrugeren vælger produktet, der maksimerer nytte, hvilket giver beslutningsreglen:
# $$
# j_{im}^* = \arg \max_{j=0,1,\dots, J} U_{imj}
# $$
#
# **Markedsandele:**
#
# I Økonometri B viser vi, at antagelsen om, at $\epsilon_{imj}$ er ekstremværdi fordelt,
# leder til markedsandele på "logit form":
# $$
# S_{mj} = \frac{\exp(V_{mj})}{\sum_{k=0}^{J} \exp(V_{mk})}
# $$
#
# $S_{mj}$ er sandsynligheden for, at forbruger $i$ vælger produkt $j$ i marked $m$.

# %% [markdown]
# ## Modellering af Markedsandele: Log-Linearisering
#
# **Markedsandel for Produkt $j$ i Marked $m$:**
# $$
# S_{mj} = \frac{\exp(V_{mj})}{\sum_{k=0}^{J} \exp(V_{mk})}
# $$
#
# **Log-markedsandel for Produkt $j$:**
# $$
# \log(S_{mj}) = V_{mj} - \log\left( \sum_{k=0}^{J} \exp(V_{mk}) \right) = V_{mj} - \Lambda_{m}
# $$
#
# **Log-differens af markedsandele mellem to produkter $j$ og $k$:**
# $$
# \log\left(\frac{S_{mj}}{S_{mk}}\right) =  V_{mj} - \Lambda_{m} - \left( V_{mk} - \Lambda_{m} \right) = V_{mj} - V_{mk}
# $$
#
# - Log-summen forsvinder når vi tager forskellen mellem produkterne.
# - Log-summen $\Lambda_{m} = \log\left( \sum_{k=0}^{J} \exp(V_{mk}) \right)$ er uafhængig af $j$ og $k$, da vi summerer over alle produkter i markedet.
#
# **Dette resulterer i en lineær model:**
# $$
# \log\left(\frac{S_{mj}}{S_{mk}}\right) = \beta(\mathbf{x}_{mj} - \mathbf{x}_{mk}) + \alpha(p_{mj} - p_{mk}) + (\xi_{mj} - \xi_{mk})
# $$

# %% [markdown]
# ## Normalisering af Nytte for Outside Good
#
# **Outside Good (ingen bilkøb):**
# - For det outside-alternativ, hvor forbrugeren vælger ikke at købe en bil, antager vi:
# $$
# V_{m0} = 0
# $$
# - Da vi ikke observerer prisen eller karakteristika for outside good, gør denne normalisering det muligt at sammenligne nytten af andre produkter relativt til ikke-køb.
#
# **Normaliseret nytte for produkt $j$:**
# - Den markeds og produkt specifikke del af nyttefunktionen for produkt $j$ bliver:
# $$
# V_{mj} = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj}
# $$
#
# **Markedsandel relativt til outside good:**
# - Ved at tage log-forskellen mellem markedsandelen for produkt $j$ og outside good ($S_{m0}$), får vi:
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj}
# $$
#
# - Normaliseringen sætter nytten af outside good til 0. Parameteren $\alpha$ er prisens marginale effekt på nytten og forventes derfor at være negativ.

# %% [markdown]
# # Part 2: Data og variable
#
# ### Indlæs relevante pakker

# %%
# Importér pakker og vælg talformat for tabeller
import pandas as pd
import numpy as np
import mymlr as mlr # see mymlr.py
pd.set_option('display.float_format', '{:.4f}'.format)

# %% [markdown]
# ## 2.1 Indlæs data

# %%
# Indlæs datasæt
df = pd.read_csv("../data/cars.csv")
df['const'] = 1 # tilføj konstant
df["market_ids"] = df["year"] # Definér "market_ids" som året for salget
pd.set_option('display.max_columns', None)  # Vis alle kolonner
pd.set_option('display.max_rows',20) # Begræns til 20 rækker
display(df.round(4)) # Vis datasættet med nye kolonner
# Out:
#       year        make              model   parent      sales    msrp  height  \
# 0     1980  alfa romeo  alfa romeo veloce      ili  2997.0000 33.6731 51.6500
# 1     1980         amc        amc concord  renault 64991.0000 14.0331 51.6000
# 2     1980         amc          amc eagle  renault 32641.0000 20.8540 55.1000
# 3     1980         amc          amc pacer  renault  2083.0000 15.7721 52.9500
# 4     1980         amc         amc spirit  renault 49723.0000 12.7213 51.6000
# ...    ...         ...                ...      ...        ...     ...     ...
# 9689  2018       volvo     volvo s90 phev    geely   437.0000 63.1415 69.9000
# 9690  2018       volvo         volvo xc60    geely 30422.0000 43.5086 65.3000
# 9691  2018       volvo    volvo xc60 phev    geely  2267.0000 53.9857 65.3000
# 9692  2018       volvo         volvo xc90    geely 30222.0000 51.9564 69.9000
# 9693  2018       volvo    volvo xc90 phev    geely  1387.0000 67.0586 69.9000
#
# ...

# %% [markdown]
# ## 2.2 Konstruer markedsandele
#
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj}
# $$
#
# Først venstresiden
# $$
# \text{dlogS}=\log\left(\frac{S_{mj}}{S_{m0}}\right)
# $$

# %%
# Beregn markedsandele Smj baseret på antagelsen om, 
# - at hver husholdning har 2 biler
# - og køber en ny bil hvert 2.5 år
df["Smj"] = 2.5 * df["sales"] / df["number_households"]

# Beregn andelen af husholdninger uden ny bil, baseret på de beregnede Smj værdier
df["Sm0"] = 1 - df.groupby("year")["Smj"].transform("sum")

# Forskellen i log-markedsandel mellem en given bil og andelen uden ny bil
df["dlogS"] = np.log(df["Smj"] / df["Sm0"])

# %% [markdown]
# ## 2.3 Priser og produktkarakteristika
#
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj}
# $$
#
# Nu de forklarende variable
# - $\mathbf{x}_{mj}$: Observerbare karakteristika for produkt $j$ i marked $m$:
#
#         "log_height","log_footprint","log_hp","log_mpg",
#         "log_curbweight","log_number_trims",
#          "releaseYear","yearsSinceDesign"
# - $p_{mj}$: Pris for produkt $j$ i marked $m$.
#     - manufacturer suggested retail price skaleret fra $1000$ til $10.000$
#             "msrp" x 0.1

# %%
# Priser, pmj
df["prices"] = df["msrp"].copy()*0.1 # Skaler priserne fra 1000$ til 10.000$

# Liste med x variable (vehicle attributes, xmj) - variable findes i df
Xvar = ["log_height","log_footprint","log_hp","log_mpg",
        "log_curbweight","log_number_trims",
       "releaseYear","yearsSinceDesign"]

# %% [markdown]
# ## 2.4 Dummyvariable
# Dummier kan absorbere systematiske komponenter af $\xi_{mj}$.
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj}
# $$
# Dummies for
# - **biltyper** (sport, EV, truck, suv, van)
# - **kalender år** (reference kategori: $1980$)
# - **bilmærke** (reference kategori: Volvo)

# %% [markdown]
# ### Dummies

# %%
# Liste med dummy variable for biltyper - findes allerede i df
D_type= ["sport","EV","truck","suv","van"] 

# Opret dummies for år og fjern 1980 som referencekategori, konverter til int for sikkerhed
year_dummies = pd.get_dummies(df["year"], prefix='y').astype(int)

# Opret dummies for bilproducenter og fjern Volvo som referencekategori
make_dummies = pd.get_dummies(df["make"]).astype(int)

# Kolonnenavne for dummies
D_year = year_dummies.columns.tolist()  # Konverter Int64Index til en liste af strenge
D_make = make_dummies.columns.tolist()  # Konverter Int64Index til en liste af strenge
D_year.remove("y_1980") # referencekategori er 1980
D_make.remove("volvo")  # referencekategori er Volvo

# Saml data og dummies i en ny dataframe, X
X = pd.concat([df, year_dummies, make_dummies], axis=1)
print(f'{len(D_year)} årsdummies og {len(D_make)} mærkedummies')
# Out:
# 38 årsdummies og 61 mærkedummies

# %%
# Vis antal observationer i hver biltype og i referencegruppen
import matplotlib.pyplot as plt

# Nogle biler tilhører flere af de fem kategorier; referencegruppen har alle dummies lig nul
sums = X[D_type].sum()
sums["referencekategori"] = X[D_type].eq(0).all(axis=1).sum()

sums.plot(kind='bar', figsize=(8, 4))
plt.ylabel('Antal obs')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.5 Deskriptiv statistik
#
# Vi begynder med priser, markedsandele og centrale produktkarakteristika. Prisen måles i 10.000 dollars, mens $S_{jm}$ er produktets andel af det potentielle marked.

# %%
# Beregn og vis deskriptiv statistik for priser, markedsandele og produktegenskaber
X['market_share_pct'] = 100 * X['Smj']
desc_vars = ['prices', 'market_share_pct', 'hp', 'mpg', 'curbweight', 'footprint', 'number_trims']
descriptive = X[desc_vars].describe(percentiles=[0.1, 0.5, 0.9]).T
descriptive.index = ['Pris ($10.000)', 'Markedsandel (%)', 'Hestekræfter', 'MPG',
                     'Vægt', 'Footprint', 'Antal varianter']
display(descriptive[['mean', 'std', '10%', '50%', '90%']].round(3))

# Vis udviklingen i markedet og den salgsvægtede gennemsnitspris over tid
year_stats = X.groupby('year').agg(
    **{'Bilmarkedet': ('Smj', 'sum'), 'Outside good': ('Sm0', 'first')})
year_stats['Gennemsnitspris'] = (X['prices'] * X['sales']).groupby(X['year']).sum() / X.groupby('year')['sales'].sum()

fig, axes = plt.subplots(1, 2, figsize=(10, 3.8))
year_stats[['Bilmarkedet', 'Outside good']].plot(ax=axes[0])
year_stats['Gennemsnitspris'].plot(ax=axes[1], color='tab:red')
axes[0].set(title='Markedsandele', ylabel='Andel', xlabel='År')
axes[1].set(title='Salgsvægtet gennemsnitspris', ylabel='Pris ($10.000)', xlabel='År')
fig.tight_layout()
plt.show()
# Out:
#                        mean       std        10%        50%        90%
# Pris ($10.000)       3.6050    1.7130     1.8670     3.1820     5.9680
# Markedsandel (%)     0.1420    0.2100     0.0040     0.0640     0.3680
# Hestekræfter       192.1820   83.8820    94.0000   175.0000   303.0000
# MPG                 20.9360    6.5830    15.0000    19.0000    28.0000
# Vægt              3561.2110  897.7660  2465.0000  3470.5000  4733.0000
# Footprint        13392.6300 1968.9150 11020.1110 13330.0640 15958.0000
# Antal varianter      5.1260   10.1880     1.0000     3.0000     9.0000

# %% [markdown]
# ## 2.6 Scatterplots, regressionslinjer og binscatter
#
# De grå punkter viser de enkelte bilmodeller. Binscatter-punkterne viser gennemsnittet af $x$ og $y$ inden for 20 lige store grupper sorteret efter $x$.

# %%
# Vis rå observationer, binscatter og simpel regressionslinje for to variabelpar
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlr.binscatter(X['hp'], X['prices'], ax=axes[0],
               xlabel='Hestekræfter', ylabel='Pris ($10.000)')
mlr.binscatter(X['curbweight'], X['mpg'], ax=axes[1],
               xlabel='Vægt', ylabel='Miles per gallon')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2.7 Multikollinearitet
#
# Multikollinearitet giver ikke skæve OLS-estimater, men gør det vanskeligere at isolere effekten af den enkelte variabel. For regressor $x_j$ gælder
#
# $$
# \operatorname{Var}(\hat\beta_j|X)=\frac{\sigma^2}{SST_j(1-R_j^2)},
# $$
#
# hvor $R_j^2$ kommer fra en regression af $x_j$ på de øvrige regressorer. Faktoren $1/(1-R_j^2)$ kaldes ofte variance inflation factor (VIF).

# %%
# Vis korrelationerne mellem pris og centrale produktegenskaber
corr_vars = ['prices'] + Xvar[:6]
corr = X[corr_vars].corr()

fig, ax = plt.subplots(figsize=(7, 5))
image = ax.imshow(corr, vmin=-1, vmax=1, cmap='coolwarm')
ax.set(xticks=range(len(corr_vars)), yticks=range(len(corr_vars)),
       xticklabels=corr_vars, yticklabels=corr_vars, title='Korrelationer')
ax.tick_params(axis='x', rotation=55)
# Skriv korrelationskoefficienterne med to decimaler i heatmappet
for i in range(len(corr_vars)):
    for j in range(len(corr_vars)):
        color = 'white' if abs(corr.iloc[i, j]) > 0.55 else 'black'
        ax.text(j, i, f'{corr.iloc[i, j]:.2f}', ha='center', va='center', color=color, fontsize=8)
fig.colorbar(image, ax=ax, shrink=0.8)
fig.tight_layout()
plt.show()

# Beregn VIF fra hjælpe-regressionen for hver forklarende variabel
vif = {}
for var in ['prices'] + Xvar:
    other_vars = ['const'] + [x for x in ['prices'] + Xvar if x != var]
    R2_j = mlr.ols(X[var], X[other_vars])['R_squared']
    vif[var] = [R2_j, 1 / (1 - R2_j)]
display(pd.DataFrame(vif, index=['Auxiliary R2', 'VIF']).T.round(2))
# Out:
#                   Auxiliary R2     VIF
# prices                  0.6000  2.5300
# log_height              0.7000  3.3700
# log_footprint           0.7600  4.1500
# log_hp                  0.7400  3.8100
# log_mpg                 0.4900  1.9800
# log_curbweight          0.9200 12.8900
# log_number_trims        0.1900  1.2400
# releaseYear             0.2000  1.2400
# yearsSinceDesign        0.1600  1.1900

# %% [markdown]
# # Part 3: OLS-estimation af efterspørgslen
#
# $$
# \log\left(\frac{S_{jm}}{S_{0m}}\right) = \beta \mathbf{x}_{jm} + \alpha p_{jm} + \xi_{jm}, \qquad \alpha<0
# $$
#
# hvor:
# - $m$ refererer til **markedet** (her **året**).
# - $S_{jm}$: Markedsandel af produkt $j$ i marked $m$.
# - $S_{0m}$: Markedsandel for det "outside good" (ingen bilkøb) i marked $m$.
# - $\mathbf{x}_{jm}$: Observerbare produktkarakteristika.
# - $p_{jm}$: Pris for produkt $j$ i marked $m$.
# - $\xi_{jm}$: Uobserverbare produktkarakteristika.
#
# Vi estimerer fem versioner af modellen, som adskiller sig ved, hvilke observerbare komponenter af $\xi_{jm}$ de absorberer.

# %% [markdown]
# #### Model 1: Baseline specifikation med kun priser ($p_{jm}$):
# $$
# \log\left(\frac{S_{jm}}{S_{0m}}\right) = \beta_0 + \alpha p_{jm} + \epsilon_{jm}
# $$
#
# #### Model 2: Priser og produktkarakteristika ($\mathbf{x}_{jm}$):
# $$
# \log\left(\frac{S_{jm}}{S_{0m}}\right) = \beta_0 + \alpha p_{jm} + \sum_k \beta_k x_{jm,k} + \epsilon_{jm}
# $$
#
# #### Model 3: Tilføjer dummies for biltyper (sport, EV, truck, SUV, van):
# $$
# \log\left(\frac{S_{jm}}{S_{0m}}\right) = \beta_0 + \alpha p_{jm} + \sum_k \beta_k x_{jm,k} + \sum_h \delta_h D^{\text{type}}_{h,jm} + \epsilon_{jm}
# $$
#
# #### Model 4: Tilføjer årsdummies for at kontrollere for markedsvirkninger:
# $$
# \log\left(\frac{S_{jm}}{S_{0m}}\right) = \beta_0 + \alpha p_{jm} + \sum_k \beta_k x_{jm,k} + \sum_h \delta_h D^{\text{type}}_{h,jm} + \sum_y \gamma_y D^{\text{year}}_{y,m} + \epsilon_{jm}
# $$
#
# #### Model 5: Fuldspecifikation med bilmærke-dummies (fixed effects for mærker):
# $$
# \log\left(\frac{S_{jm}}{S_{0m}}\right) = \beta_0 + \alpha p_{jm} + \sum_k \beta_k x_{jm,k} + \sum_h \delta_h D^{\text{type}}_{h,jm} + \sum_y \gamma_y D^{\text{year}}_{y,m} + \sum_\ell \eta_\ell D^{\text{make}}_{\ell,j} + \epsilon_{jm}
# $$
#
# **Bemærk**: I denne opsætning svarer marked $m$ til året ($m = t$).

# %% [markdown]
# ## 3.1 Estimer modellerne

# %%
# Estimér de fem efterspørgselsmodeller med gradvist flere kontroller
m1 = mlr.ols(y=X["dlogS"], X=X[['const','prices']] )
m2 = mlr.ols(y=X["dlogS"], X=X[['const','prices'] + Xvar] )
m3 = mlr.ols(y=X["dlogS"], X=X[['const','prices'] + Xvar + D_type] )
m4 = mlr.ols(y=X["dlogS"], X=X[['const','prices'] + Xvar + D_type + D_year] )
m5 = mlr.ols(y=X["dlogS"], X=X[['const','prices'] + Xvar + D_type + D_year + D_make] )

models = [m1, m2, m3, m4, m5]

# Uncomment to see the detailed summary of all models
# mlr.summary(models)

# Kompakt oversigt: koefficienten på pris er alpha
results = pd.DataFrame({
    'alpha_hat': [m['beta_hat'].ravel()[m['lbl_X'].index('prices')] for m in models],
    'SE(alpha_hat)': [m['se'].ravel()[m['lbl_X'].index('prices')] for m in models],
    'R2': [m['R_squared'] for m in models],
    'Produktkarakteristika': ['Nej', 'Ja', 'Ja', 'Ja', 'Ja'],
    'Type-dummies': ['Nej', 'Nej', 'Ja', 'Ja', 'Ja'],
    'Års-dummies': ['Nej', 'Nej', 'Nej', 'Ja', 'Ja'],
    'Mærke-dummies': ['Nej', 'Nej', 'Nej', 'Nej', 'Ja']
}, index=[f'Model {i}' for i in range(1, 6)])
display(results.round(4))
# Out:
#          alpha_hat  SE(alpha_hat)     R2 Produktkarakteristika Type-dummies  \
# Model 1    -0.3733         0.0110 0.1062                   Nej          Nej
# Model 2    -0.2031         0.0139 0.4349                    Ja          Nej
# Model 3    -0.1787         0.0139 0.4569                    Ja           Ja
# Model 4    -0.2982         0.0142 0.5065                    Ja           Ja
# Model 5    -0.3367         0.0174 0.5889                    Ja           Ja
#
#         Års-dummies Mærke-dummies
# Model 1         Nej           Nej
# Model 2         Nej           Nej
# Model 3         Nej           Nej
# Model 4          Ja           Nej
# Model 5          Ja            Ja

# %% [markdown]
# ## 3.2 Hvordan ændres prisestimatet?
#
# Figuren følger $\hat\alpha$ gennem de fem specifikationer. Ændringerne viser, at prisestimatet er følsomt over for, hvilke variable der holdes faste; de viser ikke i sig selv, hvilken model der identificerer den kausale effekt.

# %%
# Sammenlign prisestimater og 95 pct. konfidensintervaller på tværs af modeller
alpha_hat = results['alpha_hat'].to_numpy()
se_alpha = results['SE(alpha_hat)'].to_numpy()

fig, ax = plt.subplots(figsize=(7, 3.8))
ax.errorbar(range(1, 6), alpha_hat, yerr=1.96 * se_alpha, fmt='o-', capsize=4)
ax.axhline(0, color='black', linewidth=1)
ax.set(xticks=range(1, 6), xlabel='Model', ylabel=r'$\hat\alpha$ med 95% CI',
       title='Priskoefficienten på tværs af specifikationer')
plt.show()

# %% [markdown]
# ## 3.3 Test af blokke af variable
#
# Vi tester successivt, om type-, års- og mærkedummierne er samlet insignifikante. F-testet sammenligner den urestrikterede og den restrikterede model. Wald-testet skriver den samme hypotese som $H_0:R\beta=0$. Under de klassiske antagelser gælder her $W=qF$.

# %%
# Test type-, års- og mærkedummies som blokke med både F- og Wald-test
block_tests = [
    ('Biltype', m3, m2, D_type),
    ('År', m4, m3, D_year),
    ('Bilmærke', m5, m4, D_make)
]

for name, m_ur, m_r, variables in block_tests:
    print(f'\n{name}: H0: alle koefficienter i blokken er nul')
    mlr.Ftest(m_ur, m_r)
    indices = [m_ur['lbl_X'].index(var) for var in variables]
    R = np.eye(m_ur['p'])[indices]
    r = np.zeros((len(variables), 1))
    mlr.Waldtest(m_ur, R, r)
# Out:
# Biltype: H0: alle koefficienter i blokken er nul
# F-test: F(5, 9679) = 78.4193
# 5% critical value = 2.2150, p-value = 0.0000
# Wald test: chi2(5) = 392.0965
# 5% critical value = 11.0705, p-value = 0.0000
#
# År: H0: alle koefficienter i blokken er nul
# F-test: F(38, 9641) = 25.5245
# 5% critical value = 1.4061, p-value = 0.0000
# Wald test: chi2(38) = 969.9296
# 5% critical value = 53.3835, p-value = 0.0000
#
# Bilmærke: H0: alle koefficienter i blokken er nul
# F-test: F(61, 9580) = 31.4798
# 5% critical value = 1.3167, p-value = 0.0000
# Wald test: chi2(61) = 1920.2684
# 5% critical value = 80.2321, p-value = 0.0000

# %% [markdown]
# ## 3.4 Fra simpel regression til ceteris paribus: FWL
#
# Lad $Z$ indeholde alle kontroller i model 5 bortset fra pris. Frisch-Waugh-Lovell kan implementeres i tre trin:
#
# 1. Regressér $y$ på $Z$ og gem residualerne $\tilde y=M_Zy$.
# 2. Regressér pris på $Z$ og gem residualerne $\tilde p=M_Zp$.
# 3. Regressér $\tilde y$ på $\tilde p$.
#
# $$
# \hat\alpha=\frac{\tilde p'\tilde y}{\tilde p'\tilde p}.
# $$
#
# - Venstre figur viser den simple sammenhæng mellem pris og log-markedsandel.
# - Højre figur bruger den variation i pris og markedsandel, som ikke kan forklares af de øvrige kontroller.
# - Hældningen til højre er præcis prisestimatet $\hat\alpha$ fra model 5.
# - I Part 4 bruger vi præcis samme residualisering med producent-dummies som kontroller.

# %%
# Residualisér udfald og pris med hensyn til alle kontroller (FWL)
controls = ['const'] + Xvar + D_type + D_year + D_make
y_controls = mlr.ols(X['dlogS'], X[controls])
p_controls = mlr.ols(X['prices'], X[controls])
y_tilde = pd.Series(y_controls['u_hat'].ravel(), name='Residualiseret log-andel')
p_tilde = pd.Series(p_controls['u_hat'].ravel(), name='Residualiseret pris')
fwl = mlr.ols(y_tilde, pd.DataFrame({'p_tilde': p_tilde}))

# Sammenlign den rå sammenhæng med sammenhængen mellem residualiserede variable
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlr.binscatter(X['prices'], X['dlogS'], ax=axes[0],
               xlabel='Pris', ylabel='Log-markedsandel')
mlr.binscatter(p_tilde, y_tilde, ax=axes[1],
               xlabel='Residualiseret pris',
               ylabel='Residualiseret log-markedsandel')
fig.tight_layout()
plt.show()
print(f'model 1: alpha_hat = {alpha_hat[0]:.4f}; FWL: alpha_hat = {fwl["beta_hat"].ravel()[0]:.4f}; model 5: alpha_hat = {alpha_hat[4]:.4f}')
# Out:
# model 1: alpha_hat = -0.3733; FWL: alpha_hat = -0.3367; model 5: alpha_hat = -0.3367

# %% [markdown]
# ## 3.5 Test af en fælles prisfølsomhed
#
# Model 5 antager én fælles $\alpha$. Vi tillader nu forskellige priskoefficienter for biler, SUV'er, trucks og vans. `car` er referencegruppen:
#
# $$
# \alpha_{SUV}=\alpha+\delta_{SUV},\qquad
# \alpha_{truck}=\alpha+\delta_{truck},\qquad
# \alpha_{van}=\alpha+\delta_{van}.
# $$
#
# Lad $\theta=(\alpha,\delta_{SUV},\delta_{truck},\delta_{van},\gamma')'$, hvor $\gamma$ samler de øvrige koefficienter. Den fælles prisfølsomhed svarer til
#
# $$
# H_0:\delta_{SUV}=\delta_{truck}=\delta_{van}=0
# \quad\Longleftrightarrow\quad R\theta=r,\qquad
# R=\begin{bmatrix}0&I_3&0\end{bmatrix},\quad r=0_3,
# $$
#
# Her udvælger $R$ de tre interaktionskoefficienter. F-testet sammenligner den restrikterede og urestrikterede model; Wald-testet bruger $R$ og $r$ direkte.

# %%
# Konstruér prisinteraktioner og estimér forskellige priskoefficienter efter biltype
body_types = ['suv', 'truck', 'van']
price_interactions = [f'price_{d}' for d in body_types]
for var, dummy in zip(price_interactions, body_types):
    X[var] = X['prices'] * X[dummy]

X5 = ['const', 'prices'] + Xvar + D_type + D_year + D_make
m6 = mlr.ols(X['dlogS'], X[X5 + price_interactions])
beta6 = pd.Series(m6['beta_hat'].ravel(), index=m6['lbl_X'])
alpha_by_type = {'car': beta6['prices']}
for dummy, interaction in zip(body_types, price_interactions):
    alpha_by_type[dummy] = beta6['prices'] + beta6[interaction]
display(pd.Series(alpha_by_type, name='Estimeret priskoefficient').to_frame().round(4))

# Test om alle prisinteraktioner er nul: samme priskoefficient for alle biltyper
print('H0: Priskoefficienten er ens for alle fire biltyper')
mlr.Ftest(m6, m5)
indices = [m6['lbl_X'].index(var) for var in price_interactions]
R = np.eye(m6['p'])[indices]
_ = mlr.Waldtest(m6, R, np.zeros((len(indices), 1)))

# Eksempel: test om SUV og truck har samme priskoefficient
print('\nH0: Priskoefficienten er ens for SUV og truck')
R_pair = np.zeros((1, m6['p']))
R_pair[0, m6['lbl_X'].index('price_suv')] = 1
R_pair[0, m6['lbl_X'].index('price_truck')] = -1
_ = mlr.Waldtest(m6, R_pair, np.zeros((1, 1)))
# Out:
#        Estimeret priskoefficient
# car                      -0.3476
# suv                      -0.2765
# truck                    -0.6213
# van                      -0.4054
# H0: Priskoefficienten er ens for alle fire biltyper
# F-test: F(3, 9577) = 13.7380
# 5% critical value = 2.6058, p-value = 0.0000
# Wald test: chi2(3) = 41.2139
# 5% critical value = 7.8147, p-value = 0.0000
#
# H0: Priskoefficienten er ens for SUV og truck
# Wald test: chi2(1) = 38.4695
# 5% critical value = 3.8415, p-value = 0.0000

# %% [markdown]
# # Part 4: Fixed effects og within-transformation
#
# Vi antager, at en del af $\xi_{mj}$, det uobserverbare led i vores model, er specifikt for bilproducenten (mærket). Dette giver anledning til følgende lineære model:
#
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \xi_{mj}
# $$
#
# ## 4.1 Opsplitning af $\xi_{mj}$
# Lad $\xi_{mj} = \gamma_{\text{make}} + \tilde{\xi}_{mj}$, hvor $\gamma_{\text{make}}$ er producentens fixed effect, og $\tilde{\xi}_{mj}$ er det resterende fejlled.
#
# Dermed bliver modellen:
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) = \beta \mathbf{x}_{mj} + \alpha p_{mj} + \gamma_{\text{make}} + \tilde{\xi}_{mj}
# $$

# %% [markdown]
# ## 4.2 Dummies, FWL og within-transformation
#
# Hvorfor svarer producent-dummies til at trække producentgennemsnittet fra? Regressér først en vilkårlig variabel $v_{mj}$ på et fuldt sæt producent-dummies:
#
# $$
# v_{mj}=\sum_g\pi_gD_{gj}+r_{mj}.
# $$
#
# For alle observationer fra producent $g$ er OLS-prediktionen gruppens gennemsnit:
#
# $$
# \hat v_{mj}=\hat\pi_g=\bar v_g,\qquad
# \hat r_{mj}=v_{mj}-\bar v_g.
# $$
#
# At residualisere en variabel med hensyn til producent-dummies er derfor præcis det samme som at de-meane den inden for producenten. Alle streger nedenfor betegner det relevante producentgennemsnit, ikke gennemsnittet i hele stikprøven. For at eliminere $\gamma_{\text{make}}$ trækker vi producentgennemsnittet fra hele ligningen:
#
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right) - \overline{\log\left(\frac{S_{mj}}{S_{m0}}\right)} = \beta \left(\mathbf{x}_{mj} - \overline{\mathbf{x}_{mj}}\right) + \alpha \left(p_{mj} - \overline{p_{mj}}\right) + \left(\tilde{\xi}_{mj} - \overline{\tilde{\xi}_{mj}}\right)
# $$
#
# Da $\gamma_{\text{make}}$ er konstant inden for hver gruppe, forsvinder det ved transformationen:
# $$
# \log\left(\frac{S_{mj}}{S_{m0}}\right)^{\text{demeaned}} = \beta \mathbf{x}_{mj}^{\text{demeaned}} + \alpha p_{mj}^{\text{demeaned}} + \tilde{\xi}_{mj}^{\text{demeaned}}
# $$
#
# ### Konsekvens
#
# - FWL siger, at OLS på de residualiserede variable giver de samme hældningskoefficienter som modellen med producent-dummies.
# - Fixed effects elimineres, og $\alpha$ og $\beta$ identificeres af variation inden for producent.
# - Konstantleddet og producent-effekterne estimeres ikke i within-regressionen.
# - Den samme idé bruges i paneldata, hvor observationerne de-meanes inden for individ over tid. Vi vender tilbage til dette i modulet om paneldata.

# %%
# Træk producent-gennemsnittet fra hver variabel
def within_transform(df, columns, group):
    return df[columns] - df.groupby(group)[columns].transform('mean')

# Transformér udfald og regressorer inden for producent
Zvars = ['prices'] + Xvar + D_type + D_year
Xt = within_transform(X, Zvars + ['dlogS'], group='make')

# Estimér samme model med producentdummies og within-transformation
m_dummies = mlr.ols(y=X["dlogS"], X=X[['const'] + Zvars + D_make])
m_within = mlr.ols(y=Xt["dlogS"], X=Xt[Zvars])

# Sammenlign hældningskoefficienterne fra dummy- og within-estimation
beta_dummies = pd.Series(m_dummies['beta_hat'].ravel(), index=m_dummies['lbl_X'])
beta_within = pd.Series(m_within['beta_hat'].ravel(), index=m_within['lbl_X'])
display(pd.DataFrame({'Dummies': beta_dummies, 'Within': beta_within}).loc[['prices'] + Xvar].round(4))
# Out:
#                   Dummies  Within
# prices            -0.3367 -0.3367
# log_height        -0.8707 -0.8707
# log_footprint      2.0209  2.0209
# log_hp             0.3750  0.3750
# log_mpg           -0.1240 -0.1240
# log_curbweight    -0.9774 -0.9774
# log_number_trims   1.1894  1.1894
# releaseYear       -0.4066 -0.4066
# yearsSinceDesign  -0.1103 -0.1103

# %% [markdown]
# # Part 5: Fra efterspørgselsestimater til økonomisk adfærd
#
# ## 5.1 Prisændringer og markedsandele
#
# Logitmodellen omsætter prisestimatet $\alpha$ til ændringer i markedsandele. For produktets egen pris gælder
#
# $$
# \frac{\partial S_{jm}}{\partial p_{jm}}
# =\alpha S_{jm}(1-S_{jm})<0.
# $$
#
# Hvis prisen på et andet produkt $k$ ændres, er krydseffekten
#
# $$
# \frac{\partial S_{jm}}{\partial p_{km}}
# =-\alpha S_{jm}S_{km}>0,\qquad j\neq k.
# $$
#
# - En højere egen pris reducerer produktets markedsandel.
# - Den mistede efterspørgsel flyttes til outside good og de øvrige biler.
# - Elasticiteter gør effekterne sammenlignelige på tværs af produkter.

# %% [markdown]
# ## 5.2 Egenpriselasticitet
#
# For at beregne egenpriselasticiteten $\varepsilon_j$ bruger vi følgende udtryk baseret på estimaterne fra vores logit-model:
#
# $$
# \varepsilon_{mj} \equiv \frac{dS_{mj}/S_{mj}}{dp_{mj}/p_{mj}} = \alpha \cdot p_{mj} \cdot (1 - S_{mj})
# $$

# %% [markdown]
# - Model 1: Baseline specifikation med kun priser ($p_{jm}$):
# - Model 2: Priser og produktkarakteristika ($\mathbf{x}_{jm}$):
# - Model 3: Tilføjer dummies for biltyper (sport, EV, truck, SUV, van):
# - Model 4: Tilføjer årsdummies for at kontrollere for markedsvirkninger:
# - Model 5: Fuldspecifikation med bilmærke-dummies (fixed effects for mærker):

# %%
# Beregn den gennemsnitlige egenpriselasticitet for hver af de fem modeller
elasticities = []
for i, model in enumerate(models, start=1):
    idx = model['lbl_X'].index('prices')
    alpha_i = model['beta_hat'].ravel()[idx]
    elasticity = alpha_i * X['prices'] * (1 - X['Smj'])
    elasticities.append(elasticity.mean())

display(pd.DataFrame({'Gennemsnitlig egenpriselasticitet': elasticities},
                     index=[f'Model {i}' for i in range(1, 6)]).round(3))
# Out:
#          Gennemsnitlig egenpriselasticitet
# Model 1                            -1.3440
# Model 2                            -0.7310
# Model 3                            -0.6440
# Model 4                            -1.0740
# Model 5                            -1.2120

# %% [markdown]
# ## 5.3 Fordelingen af egenpriselasticiteter
#
# Selv om model 5 har én fælles priskoefficient, varierer elasticiteten med produktets pris og markedsandel. Efterspørgslen er elastisk, når $|\varepsilon_{jm}|>1$.

# %%
# Beregn og opsummér fordelingen af egenpriselasticiteter i model 5
elasticity_m5 = results.loc['Model 5', 'alpha_hat'] * X['prices'] * (1 - X['Smj'])
elasticity_summary = elasticity_m5.quantile([0.1, 0.5, 0.9]).rename(
    index={0.1: '10%', 0.5: 'Median', 0.9: '90%'})
elasticity_summary['Gennemsnit'] = elasticity_m5.mean()
elasticity_summary['Andel med |elasticitet| < 1'] = (elasticity_m5.abs() < 1).mean()
display(elasticity_summary.to_frame('Model 5').round(3))

# Histogram over egenpriselasticiteter med grænse for enhedselasticitet
fig, ax = plt.subplots(figsize=(7, 3.8))
ax.hist(elasticity_m5, bins=40, density=True, alpha=0.75)
ax.axvline(-1, color='black', linestyle='--', label='Enhedselasticitet')
ax.axvline(elasticity_m5.mean(), color='tab:red', label='Gennemsnit')
ax.set(xlabel='Egenpriselasticitet', ylabel='Tæthed',
       title='Fordeling af egenpriselasticiteter: Model 5')
ax.legend()
plt.show()
# Out:
#                              Model 5
# 10%                          -2.0080
# Median                       -1.0700
# 90%                          -0.6270
# Gennemsnit                   -1.2120
# Andel med |elasticitet| < 1   0.4430

# %% [markdown]
# ## 5.4 Krydspriselasticiteter og IIA
#
# For $j\neq k$ er krydspriselasticiteten
#
# $$
# \varepsilon_{jk}
# =\frac{\partial S_{jm}}{\partial p_{km}}\frac{p_{km}}{S_{jm}}
# =-\alpha p_{km}S_{km}>0.
# $$
#
# Logitmodellens IIA-egenskab ses også fra
#
# $$
# \frac{S_{jm}}{S_{\ell m}}=\exp(\delta_{jm}-\delta_{\ell m}).
# $$
#
# - For en given prisændring på produkt $k$ er $\varepsilon_{jk}$ ens for alle $j\neq k$.
# - Modellen skelner derfor ikke mellem nære og fjerne substitutter i de procentvise krydseffekter.
# - En prisstigning på en pickup flytter proportionalt lige meget efterspørgsel til andre pickups og til små personbiler.

# %%
# Elasticitetsmatrix for de fem mest solgte biler i det seneste år
latest_year = X['year'].max()
market = X.loc[X['year'].eq(latest_year)].nlargest(5, 'sales').copy()
labels = (market['make'].astype(str).str.title() + ' ' +
          market['model'].astype(str).str.title()).tolist()

alpha = results.loc['Model 5', 'alpha_hat']
p = market['prices'].to_numpy()
s = market['Smj'].to_numpy()
E = np.tile(-alpha * p * s, (len(market), 1))
np.fill_diagonal(E, alpha * p * (1 - s))

print(f'Elasticiteter i {latest_year}: rækker er efterspørgsel, søjler er priser')
display(pd.DataFrame(E, index=labels, columns=labels).round(3))
# Out:
# Elasticiteter i 2018: rækker er efterspørgsel, søjler er priser
#                                Ford Ford F Series  \
# Ford Ford F Series                        -1.4080
# Chevrolet Chevrolet Silverado              0.0240
# Ram Ram Pickup                             0.0240
# Toyota Toyota Rav4                         0.0240
# Nissan Nissan Rogue                        0.0240
#
#                                Chevrolet Chevrolet Silverado  Ram Ram Pickup  \
# Ford Ford F Series                                    0.0160          0.0150
# Chevrolet Chevrolet Silverado                        -1.3690          0.0150
# Ram Ram Pickup                                        0.0160         -1.4200
# Toyota Toyota Rav4                                    0.0160          0.0150
# Nissan Nissan Rogue                                   0.0160          0.0150
#
#                                Toyota Toyota Rav4  Nissan Nissan Rogue
# ...

# %% [markdown]
# ## 5.5 Hvorfor er IIA vigtig?
#
# Når prisen på produkt $j$ stiger, afhænger virksomhedens tab ikke kun af faldet i $S_j$, men også af **hvor kunderne går hen**.
#
# - Går de til en konkurrents produkt, er salget tabt.
# - Går de til et andet produkt fra samme virksomhed, bliver en del af salget internt i virksomheden.
# - En multiproduktvirksomhed tager derfor højde for kannibalisering mellem egne produkter.
#
# IIA bestemmer disse substitutionsmønstre næsten udelukkende ud fra markedsandelene. Hvis IIA er en dårlig beskrivelse af, hvilke biler der er nære substitutter, bliver modellens krydseffekter misvisende. Det påvirker beregnede markups, marginalomkostninger og kontrafaktiske analyser.

# %% [markdown]
# ## 5.6 Heterogen prisfølsomhed
#
# Den gennemsnitlige egenpriselasticitet er omtrent $-1.34$, $-0.73$, $-0.64$, $-1.07$ og $-1.21$ i model 1-5. Priskoefficienten og elasticiteten er altså følsomme over for modelspecifikationen.
#
# Interaktionsmodellen i Part 3 tillader desuden, at $\alpha$ varierer med biltypen:
#
# $$
# \varepsilon_{jj}=\alpha_{t(j)}p_j(1-S_j),\qquad
# \varepsilon_{jk}=-\alpha_{t(k)}p_kS_k.
# $$
#
# - F- og Wald-testet afviser en fælles priskoefficient for de fire biltyper.
# - Trucks har den største estimerede prisfølsomhed i absolut værdi; SUV'er har den mindste.
# - Heterogene priskoefficienter ændrer elasticiteterne, men fjerner ikke IIA: krydseffekten er stadig ens for alle modtagende produkter $j$.

# %% [markdown]
# ## 5.7 Fra elasticiteter til markups og marginalomkostninger
#
# ### Én virksomhed, ét produkt
#
# Hvis virksomheden vælger $p_j$, mens de øvrige priser holdes faste, er
#
# $$
# \pi_j=(p_j-c_j)M S_j(p).
# $$
#
# Førsteordensbetingelsen giver
#
# $$
# p_j-c_j=-\frac{S_j}{\partial S_j/\partial p_j}
# =-\frac{1}{\alpha(1-S_j)},\qquad
# \frac{p_j-c_j}{p_j}=-\frac{1}{\varepsilon_{jj}}.
# $$
#
# Her er $p_j-c_j$ det **absolutte markup**. For at sammenligne biler rapporterer vi i stedet
#
# $$
# \text{price-cost margin}_j=\frac{p_j-c_j}{p_j},\qquad
# \text{marginal cost share}_j=\frac{c_j}{p_j}.
# $$
#
# De to størrelser summerer til én. Den omkostningsbaserede markup rate $(p_j-c_j)/c_j$ er vanskelig at bruge her: Ved $c_j=0$ dividerer vi med nul, når $c_j$ er tæt på nul, eksploderer brøken, og når $c_j<0$, skifter den fortegn og mister sin normale økonomiske fortolkning.

# %%
# Closed-form markups og marginalomkostninger under single-product FOC
market_all = X.loc[X['year'].eq(latest_year)].copy()
market_all['markup_single'] = -1 / (alpha * (1 - market_all['Smj']))
market_all['mc_single'] = market_all['prices'] - market_all['markup_single']
market_all['margin_pct_single'] = 100 * market_all['markup_single'] / market_all['prices']
market_all['mc_share_pct_single'] = 100 * market_all['mc_single'] / market_all['prices']

# Vis gennemsnitlig price-cost margin og marginalomkostning som andel af prisen
single_results = pd.DataFrame({
    'Uvægtet gennemsnit': [market_all['margin_pct_single'].mean(), market_all['mc_share_pct_single'].mean()],
    'Salgsvægtet gennemsnit': [np.average(market_all['margin_pct_single'], weights=market_all['sales']), np.average(market_all['mc_share_pct_single'], weights=market_all['sales'])]
}, index=['Price-cost margin (%)', 'Marginalomkostning/pris (%)'])
print(f'Single-product resultater for {latest_year}')
display(single_results.round(3))

# Beregn hvor ofte OLS giver negative marginalomkostninger
negative_mc = market_all['mc_single'] < 0
sales_share = market_all.loc[negative_mc, 'sales'].sum() / market_all['sales'].sum()
print(f'Negativ marginalomkostning under single-product FOC: {negative_mc.mean():.1%} af modellerne, {sales_share:.1%} af salget')
# Out:
# Single-product resultater for 2018
#                              Uvægtet gennemsnit  Salgsvægtet gennemsnit
# Price-cost margin (%)                   86.3600                 96.9810
# Marginalomkostning/pris (%)             13.6400                  3.0190
# Negativ marginalomkostning under single-product FOC: 30.6% af modellerne, 43.1% af salget

# %% [markdown]
# ### Én virksomhed, flere produkter
#
# Virksomheden vælger nu priserne på alle sine egne produkter, mens konkurrenternes priser holdes faste. Lad $\mathcal F$ være virksomhedens produkter. Førsteordensbetingelsen for prisen på produkt $j$ er
#
# $$
# S_j+\sum_{k\in\mathcal F}(p_k-c_k)\frac{\partial S_k}{\partial p_j}=0.
# $$
#
# Definér $\Delta_{jk}=-\partial S_k/\partial p_j$. Da er ligningssystemet og dets løsning
#
# $$
# \Delta_{\mathcal F}(\mathbf p_{\mathcal F}-\mathbf c_{\mathcal F})
# =\mathbf S_{\mathcal F}
# \quad\Longrightarrow\quad
# \mathbf p_{\mathcal F}-\mathbf c_{\mathcal F}
# =\Delta_{\mathcal F}^{-1}\mathbf S_{\mathcal F}.
# $$
#
# - Krydspriseffekterne afgør, hvor meget virksomheden internaliserer substitution mellem egne produkter.
# - Under simpel logit med fælles $\alpha$ bliver markuppet ens for virksomhedens produkter: $-1/[\alpha(1-S_{\mathcal F})]$.

# %%
# Beregn multiproduct-markups ved at løse FOC-ligningssystemet for hvert firma
market_all['markup_multi'] = np.nan

for firm, rows in market_all.groupby('parent').groups.items():
    # Markedsandele for alle produkter, som firmaet ejer
    s_f = market_all.loc[rows, 'Smj'].to_numpy()

    # Delta_f indeholder minus de egne og krydsende prisafledte
    Delta_f = -alpha * (np.diag(s_f) - np.outer(s_f, s_f))

    # Løs Delta_f @ markup_f = s_f, som følger af firmaets FOC
    market_all.loc[rows, 'markup_multi'] = np.linalg.solve(Delta_f, s_f)

# Beregn marginalomkostninger og dimensionsløse price-cost margins
market_all['mc_multi'] = market_all['prices'] - market_all['markup_multi']
market_all['margin_pct_multi'] = 100 * market_all['markup_multi'] / market_all['prices']
market_all['mc_share_pct_multi'] = 100 * market_all['mc_multi'] / market_all['prices']

# Sammenlign resultaterne for de største producenter
firm_results = market_all.groupby('parent').agg(
    products=('model', 'size'), firm_share=('Smj', 'sum'),
    margin_single=('margin_pct_single', 'mean'), margin_multi=('margin_pct_multi', 'mean'),
    mc_share=('mc_share_pct_multi', 'mean')
).sort_values('firm_share', ascending=False).rename(columns={
    'products': 'Produkter', 'firm_share': 'Virksomhedsandel',
    'margin_single': 'Margin: ét produkt (%)', 'margin_multi': 'Margin: flere produkter (%)',
    'mc_share': 'Marginalomkostning/pris (%)'})
print(f'Illustrative resultater for {latest_year}')
display(firm_results.head(10).round(3))
# Out:
# Illustrative resultater for 2018
#             Produkter  Virksomhedsandel  Margin: ét produkt (%)  \
# parent
# gm                 42            0.0580                 86.5830
# toyota             39            0.0500                 85.8660
# ford               26            0.0490                 90.8120
# fiat               27            0.0430                 96.6390
# honda              17            0.0320                 96.7830
# nissan             28            0.0290                 90.8990
# hyundai            30            0.0250                108.5290
# subaru              7            0.0130                108.1920
# volkswagen         29            0.0120                 68.8500
# bmw                20            0.0070                 63.7230
#
#             Margin: flere produkter (%)  Marginalomkostning/pris (%)
# parent
# gm                              91.7620                       8.2380
# toyota                          90.2480                       9.7520
# ...

# %% [markdown]
# ### Fordelingen af markups og marginalomkostninger
#
# Vi sammenligner de samme biler under to antagelser om ejerskab: Hver bilmodel sælges af en separat single-product-virksomhed, eller bilmodeller med samme `parent` tilhører en multiproduktvirksomhed. Marginalomkostninger og markups vises relativt til bilens pris, og histogrammerne vægtes med bilmodellernes salg.

# %%
# Brug salg som histogramvægte
weights = market_all['sales']

# Brug fælles bins, så single- og multiproduct-fordelinger kan sammenlignes
mc_bins = np.histogram_bin_edges(np.r_[market_all['mc_share_pct_single'], market_all['mc_share_pct_multi']], bins=30)
margin_bins = np.histogram_bin_edges(np.r_[market_all['margin_pct_single'], market_all['margin_pct_multi']], bins=30)

# Plot salgsvægtede histogrammer for priser, andele, marginalomkostninger og markups
with plt.rc_context({'font.size': 10}):
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))

    axes[0, 0].hist(market_all['prices'], bins=30, weights=weights, color='tab:blue', alpha=0.65, edgecolor='black')
    axes[0, 0].set(title='Prices (Sales-Weighted)', xlabel='Price', ylabel='Weighted Frequency')
    axes[0, 1].hist(market_all['Smj'], bins=30, weights=weights, color='tab:blue', alpha=0.65, edgecolor='black')
    axes[0, 1].set(title='Market Shares (Sales-Weighted)', xlabel='Market Share', ylabel='Weighted Frequency')

    axes[1, 0].hist(market_all['mc_share_pct_single'], bins=mc_bins, weights=weights, color='tab:blue', alpha=0.65, edgecolor='black', label='Single-product')
    axes[1, 0].hist(market_all['mc_share_pct_multi'], bins=mc_bins, weights=weights, color='orange', alpha=0.65, edgecolor='black', label='Multiproduct')
    axes[1, 0].axvline(0, color='black', linewidth=1)
    axes[1, 0].set(title='Marginal Cost Shares (Sales-Weighted)', xlabel='Marginal Cost / Price (%)', ylabel='Weighted Frequency')

    axes[1, 1].hist(market_all['margin_pct_single'], bins=margin_bins, weights=weights, color='tab:blue', alpha=0.65, edgecolor='black', label='Single-product')
    axes[1, 1].hist(market_all['margin_pct_multi'], bins=margin_bins, weights=weights, color='orange', alpha=0.65, edgecolor='black', label='Multiproduct')
    axes[1, 1].set(title='Price-Cost Margins (Sales-Weighted)', xlabel='(Price - Cost) / Price (%)', ylabel='Weighted Frequency')

    for ax in axes.ravel(): ax.grid(True, alpha=0.6); ax.set_axisbelow(True)
    axes[1, 0].legend(); axes[1, 1].legend()
    fig.tight_layout(); plt.show()

# %% [markdown]
# ### Hvad viser beregningen?
#
# - OLS-estimatet giver negative marginalomkostninger for mange biler allerede under single-product FOC. Det skyldes, at den estimerede prisfølsomhed er for lille til at give plausible markups.
# - Multiprodukt-markuppet er endnu højere, fordi virksomheden internaliserer, at nogle kunder skifter til dens andre biler.
# - Under IIA drives denne forskel af virksomhedens samlede markedsandel, ikke af hvor ens dens biler er.
# - Implausible omkostninger er derfor en økonomisk advarsel om efterspørgselsmodel, prisendogenitet og antagelser om prissætning.
#
# Grieco, Murry og Yurukoglu korrigerer for prisendogenitet med instrumentvariable og finder en større prisfølsomhed i absolut værdi. Det reducerer de beregnede markups og giver mere plausible marginalomkostninger. I hjemmeopgaven skal I selv estimere modellen med IV og undersøge, hvordan resultaterne ændres.

# %% [markdown]
# # Part 6: Kan vi stole på prisestimatet?
#
# ## 6.1 Endogenitetsproblemet
#
# En kausal fortolkning af prisestimatet kræver blandt andet
#
# $$
# E(\xi_{jm}\mid \mathbf{x}_{jm},p_{jm})=0.
# $$
#
# Problemet er, at uobserveret kvalitet, brand-image eller efterspørgselschok kan påvirke både pris og efterspørgsel:
#
# $$
# \operatorname{Cov}(p_{jm},\xi_{jm})\neq 0.
# $$
#
# - OLS-estimatet af $\alpha$ er da skævt og inkonsistent.
# - Positiv samvariation mellem pris og uobserveret kvalitet vil typisk gøre $\hat\alpha$ mindre negativ.
# - Fejlen føres videre til elasticiteter, markups og beregnede marginalomkostninger.

# %% [markdown]
# ## 6.2 Hvad kan dummies og fixed effects gøre?
#
# - **Årsdummies** absorberer fælles forhold i et år, som påvirker alle biler.
# - **Mærke-fixed effects** absorberer permanente forskelle mellem bilmærker.
# - De kan reducere omitted-variable bias, hvis de absorberede forhold påvirker både pris og markedsandel.
# - Ændringerne i $\hat\alpha$ på tværs af model 1--5 er konsistente med udeladte variable, men beviser ikke endogenitet.
#
# Selv i model 5 kan modelspecifik uobserveret kvalitet variere inden for mærke og år. Dummies løser derfor ikke nødvendigvis prisendogeniteten.

# %% [markdown]
# ## 6.3 Bro til instrumentvariable
#
# Et instrument $z_{jm}$ skal skabe variation i prisen uden samtidig at påvirke den uobserverede efterspørgsel direkte:
#
# $$
# \operatorname{Cov}(z_{jm},p_{jm})\neq 0,\qquad
# \operatorname{Cov}(z_{jm},\xi_{jm})=0.
# $$
#
# Grieco, Murry og Yurukoglu bruger den reale valutakurs mellem USA og bilens oprindelsesland som instrument for pris. Under de relevante antagelser kan IV give et konsistent estimat af prisfølsomheden.
#
# I vender tilbage til bilmarkedet og estimerer modellen med IV i en senere opgave.

# %% [markdown]
# # Part 7: Bro til heteroskedasticitet
#
# Homoskedasticitet kræver
#
# $$
# \operatorname{Var}(\xi_{jm}\mid X)=\sigma^2.
# $$
#
# Figurerne undersøger både den betingede middelværdi og spredningen af residualerne:
#
# - Punkterne til venstre viser gennemsnitlige residualer. Systematiske afvigelser fra nul peger på funktionel form eller udeladte variable.
# - Figuren til højre viser gennemsnittet af $\hat u^2$. Bemærk, at
#
# $$
# E(\hat u^2\mid z)=\operatorname{Var}(\hat u\mid z)+[E(\hat u\mid z)]^2.
# $$
#
# - Pris viser et moderat variansmønster, mens `number_trims` viser en tydeligere ændring i spredningen.
# - For gamle bildesigns er der få observationer og en ikke-nul middelresidual. Det er derfor ikke et rent mål for heteroskedasticitet.
#
# Figurerne er deskriptive og motiverer næste emne: heteroskedasticitet, robuste standardfejl og specifikationskontrol.

# %%
# Undersøg residualernes middelværdi og varians langs tre mulige variansdrivere
model=m5
mlr.residual_variance_plot(model, X['prices'], bins=30, xlabel='Pris ($10.000)', titles=('Residualer', 'Residualvarians i grupper'))
mlr.residual_variance_plot(model, X['number_trims'], bins=30)
mlr.residual_variance_plot(model, X['yearsSinceDesign'], bins=None)
#mlr.residual_variance_plot(model, X['mpg'], bins=10)
#mlr.residual_variance_plot(model, X['curbweight'], bins=10)
#mlr.residual_variance_plot(model, X['footprint'], bins=10)
# Out:
# Max/min mean(u_hat^2) by bins = 1.67
# Max/min mean(u_hat^2) by bins = 3.91
# Max/min mean(u_hat^2) by x values = 9.92

# %% [markdown]
# # Opsamling
#
# - Logitmodellen giver en lineær ligning for log-markedsandelen relativt til outside good.
# - Deskriptiv analyse, multikollinearitet og modelspecifikation er afgørende for fortolkningen af OLS.
# - FWL isolerer ceteris-paribus-variationen; residualisering mod gruppedummies er præcis within-transformationen.
# - Prisestimaterne bestemmer egne og krydsende elasticiteter, substitution, markups og marginalomkostninger.
# - IIA styrer diversion mellem produkter og er derfor afgørende for multiprodukt-markups og marginalomkostninger.
# - Heterogene priskoefficienter giver mere fleksible prisreaktioner, men fjerner ikke logitmodellens IIA-egenskab.
# - Dummies kan reducere omitted-variable bias; IV er nødvendig, hvis pris fortsat er korreleret med uobserveret kvalitet.
# - Residualplots peger både på mulig heteroskedasticitet og behovet for at kontrollere den betingede middelværdi.
